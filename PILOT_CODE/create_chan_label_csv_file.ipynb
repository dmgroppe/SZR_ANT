# %% [markdown]
# Simple notebook for creating a text file that lists channel names

# %%
import numpy as np
import pandas as pd
import scipy.io
import os
import ieeg_funcs as ief
import dgFuncs as dg
from sklearn import preprocessing
import sys
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# create csv file of channel names for a sub
# sub='TF'
# sub='CC'
#sub='CT'
#sub='ME'
#sub='CJ'
#sub='CO'
# sub='JW'
# sub='IB'
#sub='SV' #GRID PATIENT, CHAN NAME PROBLEM
sub='RB' #GRID PATIEND, CHAN NAME PROBLEM
sub='CV'#GRID PATIEND, CHAN NAME PROBLEM
path_dict = ief.get_path_dict()
in_fname=os.path.join(path_dict['ieeg_root'],sub,sub+'_channel_info.mat')
# in_fname=os.path.join('/Users/davidgroppe/ONGOING/SZR_SPREAD/PATIENTS/',sub,'Data',
#                       sub+'_channel_info.mat')
# in_fname=os.path.join('/Users/davidgroppe/ONGOING/SZR_SPREAD/PATIENTS/',sub,
#                       sub+'_channel_info.mat')
#in_fname='/Users/davidgroppe/ONGOING/SZR_SPREAD/PATIENTS/CJ/CJ_channel_info.mat' #88 channels
#in_fname='/Users/davidgroppe/ONGOING/TWH_DATA/CJ/CJ_channel_info.mat' #89 channels
print('Importing %s' % in_fname)
mat=scipy.io.loadmat(in_fname)
print(mat.keys())

out_fname=os.path.join(path_dict['ieeg_root'],sub,sub+'_channel_info.csv')
# out_fname=os.path.join('/Users/davidgroppe/ONGOING/SZR_SPREAD/PATIENTS/',sub,
#                       sub+'_channel_info.csv')
print('Exporting %s' % out_fname)
print('# of channels=%d' % len(mat['bi_labels'][0,:]))

txt_file=open(out_fname,'w')
for a in mat['bi_labels'][0,:]:
    print(a[0])
    txt_file.write(a[0])
    txt_file.write('\n')
txt_file.close()
# Out:
# Importing /Users/davidgroppe/ONGOING/TWH_EEG/CV/CV_channel_info.mat
# dict_keys(['__header__', '__globals__', 'bi_labels', 'bi_numbers', 'm_labels', 'group_end_index', '__version__'])
# Exporting /Users/davidgroppe/ONGOING/TWH_EEG/CV/CV_channel_info.csv
# # of channels=82
# G1_1-G1_2
# G1_2-G1_3
# G1_3-G1_4
# G1_4-G1_5
# G1_5-G1_6
# G1_6-G1_7
# G1_7-G1_8
# G2_1-G2_2
# G2_2-G2_3
# G2_3-G2_4
# G2_4-G2_5
# G2_5-G2_6
# G2_6-G2_7
# G2_7-G2_8
# G3_1-G3_2
# G3_2-G3_3
# G3_3-G3_4
# G3_4-G3_5
# G3_5-G3_6
# G3_6-G3_7
# G3_7-G3_8
# G4_1-G4_2
# G4_2-G4_3
# G4_3-G4_4
# G4_4-G4_5
# G4_5-G4_6
# G4_6-G4_7
# G4_7-G4_8
# G5_1-G5_2
# G5_2-G5_3
# G5_3-G5_4
# G5_4-G5_5
# G5_5-G5_6
# G5_6-G5_7
# G5_7-G5_8
# G6_1-G6_2
# G6_2-G6_3
# G6_3-G6_4
# G6_4-G6_5
# G6_5-G6_6
# G6_6-G6_7
# G6_7-G6_8
# G7_1-G7_2
# G7_2-G7_3
# G7_3-G7_4
# G7_4-G7_5
# G7_5-G7_6
# G7_6-G7_7
# G7_7-G7_8
# G8_1-G8_2
# G8_2-G8_3
# G8_3-G8_4
# G8_4-G8_5
# G8_5-G8_6
# G8_6-G8_7
# G8_7-G8_8
# LOF1-LOF2
# LOF2-LOF3
# LOF3-LOF4
# LPF1-LPF2
# LPF2-LPF3
# LPF3-LPF4
# LAT1-LAT2
# LAT2-LAT3
# LAT3-LAT4
# LT1-LT2
# LT2-LT3
# LT3-LT4
# LT4-LT5
# LT5-LT6
# LMIH1-LMIH2
# LMIH2-LMIH3
# LMIH3-LMIH4
# LMIH4-LMIH5
# LMIH5-LMIH6
# LPIH1-LPIH2
# LPIH2-LPIH3
# LPIH3-LPIH4
# LPIH4-LPIH5
# LPIH5-LPIH6
# LPIH6-LPIH7
# LPIH7-LPIH8
